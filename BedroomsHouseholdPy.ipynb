# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import json
import os
from sklearn import linear_model

from scipy.stats import linregress
import scipy.stats as stats

# %% [markdown]
# ### Master DataFrame

# %%
master_df = pd.read_csv("Resources/master_data.csv")
master_df.head()
# Out:
#    Postcode  House  Semi-detached  Apartment  Other dwelling  \
# 0       800     33              6       5876               4
# 1       810  14828           2642       5649              85
# 2       812   9601           1127       1549             134
# 3       820   4926           3337       6733             104
# 4       822   9415            655        168             348
#
#    No bedrooms (studios, etc)  1 bedroom  2 bedrooms  3 bedrooms  4 bedrooms  \
# 0                         172       1856        3749        2805         168
# 1                         207       1768        8552        9360        5484
# 2                          67        448        3389        6590        2353
# 3                         167       1463        7566        7580        2372
# 4                         216        873        3083        4392        1811
#
#    ...  6 or more bedrooms  Couple with no children  Couple with children  \
# 0  ...                   6                     2874                  1181
# 1  ...                 311                     6553                  8881
# 2  ...                  95                     3237                  4486
# 3  ...                 168                     5792                  4755
# 4  ...                 183                     2456                  4369
#
#    One parent with children  Other family  Sole person household  \
# 0                       395           134                   3420
# 1                      2893           425                   6996
# 2                      2032           204                   3249
# 3                      1644           220                   5987
# 4                      1989           404                   1921
#
#    Group household  People with Mental Health Conditions  Total People  \
# 0              910                                   344          7149
# 1             1737                                  1971         34330
# 2              592                                  1076         18634
# 3             1843                                  1112         19920
# 4              268                                   755         25304
#
#                    State
# 0  7: Northern Territory
# 1  7: Northern Territory
# 2  7: Northern Territory
# 3  7: Northern Territory
# 4  7: Northern Territory
#
# [5 rows x 21 columns]

# %%
com_master_df = master_df.drop(master_df[master_df["Total People"]<10000].index, inplace=False )
com_master_df
# Out:
#       Postcode  House  Semi-detached  Apartment  Other dwelling  \
# 1          810  14828           2642       5649              85
# 2          812   9601           1127       1549             134
# 3          820   4926           3337       6733             104
# 4          822   9415            655        168             348
# 7          830   9542            905       1888              16
# ...        ...    ...            ...        ...             ...
# 2595      7250  33651           3152       4202             142
# 2626      7307   8732            485         64              96
# 2627      7310  20651           2473         52             208
# 2628      7315  11357           1178         47             203
# 2630      7320  12555           1265        289              34
#
#       No bedrooms (studios, etc)  1 bedroom  2 bedrooms  3 bedrooms  \
# 1                            207       1768        8552        9360
# 2                             67        448        3389        6590
# 3                            167       1463        7566        7580
# 4                            216        873        3083        4392
# 7                             25        805        2765        6391
# ...                          ...        ...         ...         ...
# 2595                         116       2567       10629       19927
# 2626                          36        317        2029        5101
# 2627                          87       1244        5300       12894
# 2628                          31        725        2753        6894
# 2630                         100        794        3127        7944
#
#       4 bedrooms  ...  6 or more bedrooms  Couple with no children  \
# 1           5484  ...                 311                     6553
# 2           2353  ...                  95                     3237
# 3           2372  ...                 168                     5792
# 4           1811  ...                 183                     2456
# 7           2944  ...                  90                     3080
# ...          ...  ...                 ...                      ...
# 2595        8506  ...                 321                    12187
# 2626        1720  ...                  52                     3468
# 2627        3844  ...                 166                     7001
# 2628        2374  ...                  65                     4191
# 2630        2247  ...                  77                     3737
#
#       Couple with children  One parent with children  Other family  \
# 1                     8881                      2893           425
# 2                     4486                      2032           204
# 3                     4755                      1644           220
# 4                     4369                      1989           404
# 7                     4275                      2193           157
# ...                    ...                       ...           ...
# 2595                 10649                      5302           400
# 2626                  2268                       928            93
# 2627                  5360                      3261           245
# 2628                  2983                      1592           117
# 2630                  3285                      2045           147
#
#       Sole person household  Group household  \
# 1                      6996             1737
# 2                      3249              592
# 3                      5987             1843
# 4                      1921              268
# 7                      3537              566
# ...                     ...              ...
# 2595                  14883             1537
# 2626                   2762              196
# 2627                   8145              755
# 2628                   4439              238
# 2630                   5293              387
#
#       People with Mental Health Conditions  Total People  \
# 1                                     1971         34330
# 2                                     1076         18634
# 3                                     1112         19920
# 4                                      755         25304
# 7                                     1302         18501
# ...                                    ...           ...
# 2595                                  5821         51133
# 2626                                  1153         11849
# 2627                                  3536         28635
# 2628                                  1658         15635
# 2630                                  2294         17138
#
#                       State
# 1     7: Northern Territory
# 2     7: Northern Territory
# 3     7: Northern Territory
# 4     7: Northern Territory
# 7     7: Northern Territory
# ...                     ...
# 2595            6: Tasmania
# 2626            6: Tasmania
# 2627            6: Tasmania
# 2628            6: Tasmania
# 2630            6: Tasmania
#
# [852 rows x 21 columns]

# %%
com_master_df["People with Mental Health %"]=round(com_master_df["People with Mental Health Conditions"]/com_master_df["Total People"]*100,1)
com_master_df.head()
# Out:
#    Postcode  House  Semi-detached  Apartment  Other dwelling  \
# 1       810  14828           2642       5649              85
# 2       812   9601           1127       1549             134
# 3       820   4926           3337       6733             104
# 4       822   9415            655        168             348
# 7       830   9542            905       1888              16
#
#    No bedrooms (studios, etc)  1 bedroom  2 bedrooms  3 bedrooms  4 bedrooms  \
# 1                         207       1768        8552        9360        5484
# 2                          67        448        3389        6590        2353
# 3                         167       1463        7566        7580        2372
# 4                         216        873        3083        4392        1811
# 7                          25        805        2765        6391        2944
#
#    ...  Couple with no children  Couple with children  \
# 1  ...                     6553                  8881
# 2  ...                     3237                  4486
# 3  ...                     5792                  4755
# 4  ...                     2456                  4369
# 7  ...                     3080                  4275
#
#    One parent with children  Other family  Sole person household  \
# 1                      2893           425                   6996
# 2                      2032           204                   3249
# 3                      1644           220                   5987
# 4                      1989           404                   1921
# 7                      2193           157                   3537
#
#    Group household  People with Mental Health Conditions  Total People  \
# 1             1737                                  1971         34330
# 2              592                                  1076         18634
# 3             1843                                  1112         19920
# 4              268                                   755         25304
# 7              566                                  1302         18501
#
#                    State  People with Mental Health %
# 1  7: Northern Territory                          5.7
# 2  7: Northern Territory                          5.8
# 3  7: Northern Territory                          5.6
# 4  7: Northern Territory                          3.0
# 7  7: Northern Territory                          7.0
#
# [5 rows x 22 columns]

# %%
com_master_df.columns
# Out:
# Index(['Postcode', 'House', 'Semi-detached', 'Apartment', 'Other dwelling',
#        'No bedrooms (studios, etc)', '1 bedroom', '2 bedrooms', '3 bedrooms',
#        '4 bedrooms', '5 bedrooms', '6 or more bedrooms',
#        'Couple with no children', 'Couple with children',
#        'One parent with children', 'Other family', 'Sole person household',
#        'Group household', 'People with Mental Health Conditions',
#        'Total People', 'State', 'People with Mental Health %'],
#       dtype='object')

# %% [markdown]
# ### Dwelling Size DataFrame

# %%
com_master_df['Small House- 1 or 2 Bedrooms'] = (com_master_df['1 bedroom'] + com_master_df['2 bedrooms'])
com_master_df['Medium House- 3, 4 or 5 Bedrooms'] = (com_master_df['3 bedrooms']+ com_master_df['4 bedrooms']+com_master_df['5 bedrooms'])

com_master_df =com_master_df.drop(['1 bedroom','2 bedrooms','3 bedrooms','4 bedrooms','5 bedrooms'],axis=1)
House_Size_df=com_master_df.filter(['Postcode','No bedrooms (studios, etc)',
                             'Small House- 1 or 2 Bedrooms',
                             'Medium House- 3, 4 or 5 Bedrooms',
                             '6 or more bedrooms',
                            'People with Mental Health Conditions',
                            'People with Mental Health %',
                            'Total People'],axis=1)
House_Size_df.head()
# Out:
#    Postcode  No bedrooms (studios, etc)  Small House- 1 or 2 Bedrooms  \
# 1       810                         207                         10320
# 2       812                          67                          3837
# 3       820                         167                          9029
# 4       822                         216                          3956
# 7       830                          25                          3570
#
#    Medium House- 3, 4 or 5 Bedrooms  6 or more bedrooms  \
# 1                             16104                 311
# 2                              9486                  95
# 3                             10544                 168
# 4                              6547                 183
# 7                              9771                  90
#
#    People with Mental Health Conditions  People with Mental Health %  \
# 1                                  1971                          5.7
# 2                                  1076                          5.8
# 3                                  1112                          5.6
# 4                                   755                          3.0
# 7                                  1302                          7.0
#
#    Total People
# 1         34330
# 2         18634
# 3         19920
# 4         25304
# 7         18501

# %%
House_Size_df.describe()
# Out:
#           Postcode  No bedrooms (studios, etc)  Small House- 1 or 2 Bedrooms  \
# count   852.000000                  852.000000                    852.000000
# mean   3663.730047                  110.360329                   6144.252347
# std    1393.494131                  262.220385                   6114.247706
# min     810.000000                    0.000000                     66.000000
# 25%    2496.750000                   18.000000                   2229.750000
# 50%    3190.500000                   45.000000                   4006.000000
# 75%    4573.500000                  112.000000                   8041.000000
# max    7320.000000                 4492.000000                  56477.000000
#
#        Medium House- 3, 4 or 5 Bedrooms  6 or more bedrooms  \
# count                        852.000000          852.000000
# mean                       13853.076291          213.774648
# std                         9384.096028          183.252283
# min                         2428.000000            0.000000
# 25%                         7684.000000           90.000000
# 50%                        10899.500000          162.000000
# 75%                        16577.750000          276.750000
# max                        72411.000000         1363.000000
#
#        People with Mental Health Conditions  People with Mental Health %  \
# count                            852.000000                   852.000000
# mean                            2148.166667                     8.798709
# std                             1487.081845                     2.563490
# min                              330.000000                     2.200000
# 25%                             1181.750000                     6.900000
# 50%                             1679.500000                     8.700000
# 75%                             2575.250000                    10.700000
# max                            13409.000000                    16.300000
#
#         Total People
# count     852.000000
# mean    24656.708920
# std     15678.245193
# min     10043.000000
# 25%     14383.000000
# 50%     19725.000000
# 75%     29895.500000
# max    129888.000000

# %% [markdown]
# ### Household Type DataFrame

# %%
com_master_df['Family Household'] = (com_master_df['Couple with no children'] + com_master_df['Couple with children']+ com_master_df['Other family']+ com_master_df['Group household'])

#com_master_df =com_master_df.drop(['1 bedroom','2 bedrooms','3 bedrooms','4 bedrooms','5 bedrooms'],axis=1)
Household_df=com_master_df.filter(['Postcode',
                                   'Sole person household',
                                 'One parent with children',
                                 'Family Household',
                                'People with Mental Health Conditions',
                                'People with Mental Health %',
                                'Total People'],axis=1)
Household_df.head()
# Out:
#    Postcode  Sole person household  One parent with children  \
# 1       810                   6996                      2893
# 2       812                   3249                      2032
# 3       820                   5987                      1644
# 4       822                   1921                      1989
# 7       830                   3537                      2193
#
#    Family Household  People with Mental Health Conditions  \
# 1             17596                                  1971
# 2              8519                                  1076
# 3             12610                                  1112
# 4              7497                                   755
# 7              8078                                  1302
#
#    People with Mental Health %  Total People
# 1                          5.7         34330
# 2                          5.8         18634
# 3                          5.6         19920
# 4                          3.0         25304
# 7                          7.0         18501

# %%
#Finding the Weightage of each House Type based on No.of Bedrooms

model = linear_model.LinearRegression()
X,y = House_Size_df[['No bedrooms (studios, etc)','Small House- 1 or 2 Bedrooms','Medium House- 3, 4 or 5 Bedrooms','6 or more bedrooms']].values, House_Size_df['People with Mental Health Conditions'].values

model.fit(X,y)      
model.coef_
# Out:
# array([ 0.20763422,  0.03985162,  0.14424612, -0.63349393])

# %%
# Finding R Value
yhat = model.predict(X)
SS_Residual = sum((y-yhat)**2)       
SS_Total = sum((y-np.mean(y))**2)     
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X.shape[1]-1)
print(r_squared, adjusted_r_squared)

print(model.score(X, y), 1 - (1-model.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1))

#Findind the R Value from the R Squared
r_squared**(1/2)
# Out:
# 0.812911183242311 0.8120276469175994
# 0.8129111832423112 0.8120276469175995
# 0.9016158734418506

# %%
No_bedrooms =House_Size_df['No bedrooms (studios, etc)']
Small_House=House_Size_df['Small House- 1 or 2 Bedrooms']
Medium_House=House_Size_df['Medium House- 3, 4 or 5 Bedrooms']
Large_House=House_Size_df['6 or more bedrooms']
Mental_Health=House_Size_df['People with Mental Health Conditions']

# %% [markdown]
# # Plots and Analysis
#
# ## Dwelling Size
# ### Mental Health versus Houses with No Bedrooms

# %%
# Perform a linear regression on Mental Health versus Houses with No Bedrooms
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Mental_Health, No_bedrooms)

# Create equation of line to calculate predicted Mental Health rate
vc_fit = vc_slope * Mental_Health + vc_int

# %%
#Scatter Plot for Mental Health Versus House with No BedRooms

plt.scatter(Mental_Health, No_bedrooms,color='skyblue', marker="o", edgecolor="black")
plt.plot(Mental_Health,vc_fit,color='red')
plt.title(' Mental Health Versus House with No Bedrooms')
plt.xlabel('Mental_Health')
plt.ylabel('Houses with No Bedrooms')
plt.ylim(0,2000)


print(f"The r-value is:"+str(vc_r))

plt.text(6000,1500,"y="+str(round(vc_slope,2))+"x+"+str(round(vc_int,2)), fontsize=15, color="red")

plt.show()
# Out:
# The r-value is:0.08931509836931734

# %% [markdown]
# ### Mental Health versus Houses with 1 or 2 Bedrooms

# %%
# Perform a linear regression on Mental Health versus Houses with 1 or 2 Bedrooms
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Mental_Health, Small_House)

# Create equation of line to calculate predicted Mental Health rate
vc_fit = vc_slope * Mental_Health + vc_int

# %%
#Scatter Plot for Mental Health Versus House with 1 or 2 Bedrooms

plt.scatter(Mental_Health,Small_House,color='skyblue', marker="o", edgecolor="black")
plt.plot(Mental_Health,vc_fit,color='red')
plt.title(' Mental Health Versus House with 1 or 2 Bedrooms')
plt.xlabel('Mental_Health')
plt.ylabel('Houses with 1 or 2 Bedrooms')
#plt.ylim(0,2000)


print(f"The r-value is:"+str(vc_r))

plt.text(6000,45000,"y="+str(round(vc_slope,2))+"x+"+str(round(vc_int,2)), fontsize=15, color="red")

plt.show()
# Out:
# The r-value is:0.2979025407999754

# %% [markdown]
# ### Mental Health versus Houses with 3, 4 or 5 Bedrooms

# %%
# Perform a linear regression on Mental Health versus Houses with 3, 4 or 5 Bedrooms
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Mental_Health, Medium_House)

# Create equation of line to calculate predicted Mental Health rate
vc_fit = vc_slope * Mental_Health + vc_int

# %%
#Scatter Plot for Mental Health Versus House with 3, 4 or 5 Bedrooms

plt.scatter(Mental_Health,Medium_House,color='skyblue', marker="o", edgecolor="black")
plt.plot(Mental_Health,vc_fit,color='red')
plt.title(' Mental Health Versus House with 3, 4 or 5 Bedrooms')
plt.xlabel('Mental_Health')
plt.ylabel('Houses with 3, 4 or 5 Bedrooms')
#plt.ylim(0,2000)


print(f"The r-value is:"+str(vc_r))

plt.text(6000,20000,"y="+str(round(vc_slope,2))+"x+"+str(round(vc_int,2)), fontsize=15, color="red")

plt.show()
# Out:
# The r-value is:0.8810178979714299

# %% [markdown]
# ### Mental Health versus Houses with 6 or more bedrooms

# %%
# Perform a linear regression on Mental Health versus Houses with 6 or more bedrooms
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Mental_Health, Large_House)

# Create equation of line to calculate predicted Mental Health rate
vc_fit = vc_slope * Mental_Health + vc_int

# %%
#Scatter Plot for Mental Health Versus House with 6 or more bedrooms

plt.scatter(Mental_Health, Large_House,color='skyblue', marker="o", edgecolor="black")
plt.plot(Mental_Health,vc_fit,color='red')
plt.title(' Mental Health Versus House with 6 or more bedrooms')
plt.xlabel('Mental_Health')
plt.ylabel('Houses with 6 or more bedrooms')
#plt.ylim(0,2000)


print(f"The r-value is:"+str(vc_r))

plt.text(8000,1200,"y="+str(round(vc_slope,2))+"x+"+str(round(vc_int,2)), fontsize=15, color="red")

plt.show()
# Out:
# The r-value is:0.5267336349404651

# %% [markdown]
# ## Household Type

# %%
#Finding the Weightage of each House Type based on No.of Persons in the Household

model = linear_model.LinearRegression()
X,y = Household_df[['Sole person household','One parent with children','Family Household']].values, Household_df['People with Mental Health Conditions'].values

model.fit(X,y)      
model.coef_
# Out:
# array([ 0.09877298,  0.6651111 , -0.00402074])

# %%
Sole_Person=Household_df['Sole person household']
Single_Parent=Household_df['One parent with children']
Family=Household_df['Family Household']

# %% [markdown]
# ### Mental Health versus Sole Person Household

# %%
# Perform a linear regression on Mental Health versus Sole Person Household
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Mental_Health, Sole_Person)

# Create equation of line to calculate predicted Mental Health rate
vc_fit = vc_slope * Mental_Health + vc_int

# %%
#Scatter Plot for Mental Health Versus  Sole Person Household

plt.scatter(Mental_Health, Sole_Person,color='lightgreen', marker="o", edgecolor="black")
plt.plot(Mental_Health,vc_fit,color='red')
plt.title(' Mental Health Versus  Sole Person Household')
plt.xlabel('Mental_Health')
plt.ylabel(' Sole Person Household')
#plt.ylim(0,2000)


print(f"The r-value is:"+str(vc_r))

plt.text(6000,1500,"y="+str(round(vc_slope,2))+"x+"+str(round(vc_int,2)), fontsize=15, color="red")

plt.show()
# Out:
# The r-value is:0.7270003455524405

# %% [markdown]
# ### Mental Health versus Single Parent Household

# %%
# Perform a linear regression on Mental Health versus Single Parent Hosehold
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Mental_Health, Single_Parent)

# Create equation of line to calculate predicted Mental Health rate
vc_fit = vc_slope * Mental_Health + vc_int

# %%
#Scatter Plot for Mental Health Versus Single Parent Hosehold

plt.scatter(Mental_Health, Single_Parent,color='lightgreen', marker="o", edgecolor="black")
plt.plot(Mental_Health,vc_fit,color='red')
plt.title(' Mental Health Versus Single Parent Household')
plt.xlabel('Mental_Health')
plt.ylabel(' Single Parent Hosehold')
#plt.ylim(0,2000)


print(f"The r-value is:"+str(vc_r))

plt.text(6000,1500,"y="+str(round(vc_slope,2))+"x+"+str(round(vc_int,2)), fontsize=15, color="red")

plt.show()
# Out:
# The r-value is:0.8825362738567324

# %% [markdown]
# ### Mental Health versus Family Household

# %%
# Perform a linear regression on Mental Health versus Family Household
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(Mental_Health, Family)

# Create equation of line to calculate predicted Mental Health rate
vc_fit = vc_slope * Mental_Health + vc_int

# %%
#Scatter Plot for Mental Health Versus Family Household

plt.scatter(Mental_Health, Family,color='lightgreen', marker="o", edgecolor="black")
plt.plot(Mental_Health,vc_fit,color='red')
plt.title(' Mental Health Versus Family Household')
plt.xlabel('Mental_Health')
plt.ylabel('  Family Hosehold')
#plt.ylim(0,2000)


print(f"The r-value is:"+str(vc_r))

plt.text(6000,1500,"y="+str(round(vc_slope,2))+"x+"+str(round(vc_int,2)), fontsize=15, color="red")

plt.show()
# Out:
# The r-value is:0.8048954636820542
